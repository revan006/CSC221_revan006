# %% [markdown]
# <a href="https://colab.research.google.com/github/revan006/CSC221_revan006/blob/main/Assignment_16_17.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 1.1 Running Python
# In this section, we'll showcase how to run Python code.

# Simple print statement
print("Hello, Python!")

# Arithmetic operation
result = 5 + 3
print("Result of 5 + 3:", result)

# 1.2 Python Programs
# Let's explore how to create and run Python programs.

# Define a simple function
def greet(name):
    return f"Hello, {name}!"

# Call the function
greeting = greet("John")
print(greeting)

# 1.3 Primitives, Variables, and Expressions
# Understanding data types, variables, and expressions.

# Declare a variable
age = 25

# Perform arithmetic operations
double_age = age * 2
print("Double age:", double_age)

# Concatenate strings
name = "Alice"
greeting = "Hello, " + name
print(greeting)


# 1.4 Arithmetic Operators
# Explore arithmetic operators and their usage.

# Basic arithmetic operations
result_add = 10 + 5
result_mul = 10 * 5
result_div = 10 / 5
result_mod = 10 % 3

print("Addition:", result_add)
print("Multiplication:", result_mul)
print("Division:", result_div)
print("Modulo:", result_mod)

# 1.5 Conditionals and Control Flow
# Demonstrate conditional statements and control flow.

# Conditional statement
num = 7
if num % 2 == 0:
    print("Even number")
else:
    print("Odd number")

# Looping
for i in range(3):
    print("Iteration", i)

# 1.6 Text Strings
# Work with text strings and their operations.

# String manipulation
text = "Python is awesome!"
print("Length of text:", len(text))
print("Uppercase:", text.upper())
print("Substring:", text[0:6])

# 1.7 File Input and Output
# Working with files in Python.

# Writing to a file
with open("output.txt", "w") as file:
    file.write("Hello, File!")

# Reading from a file
with open("output.txt", "r") as file:
    content = file.read()
    print("File Content:", content)

# 1.8 Lists
# Understanding lists and their operations.

# Create a list
numbers = [1, 2, 3, 4, 5]

# Accessing elements
print("First element:", numbers[0])

# Modifying elements
numbers[1] = 10
print("Updated list:", numbers)

# 1.9 Tuples
# Exploring tuples and their immutability.

# Create a tuple
coordinates = (4, 5)

# Accessing elements
print("X-coordinate:", coordinates[0])

# 1.10 Sets
# Utilizing sets for unique elements.

# Create a set
unique_numbers = {1, 2, 3, 4, 5, 1, 2}

# Display unique elements
print("Unique Numbers:", unique_numbers)

# 1.11 Dictionaries
# Understanding dictionaries and key-value pairs.

# Create a dictionary
person = {"name": "John", "age": 25, "city": "New York"}

# Accessing values
print("Name:", person["name"])

# 1.12 Iteration and Looping
# Iterating through elements using loops.

# Loop through a list
for num in numbers:
    print("Number:", num)

# Loop through a dictionary
for key, value in person.items():
    print(f"{key}: {value}")

# 1.13 Functions
# Defining and using functions in Python.

# Define a function
def add_numbers(a, b):
    return a + b

# Call the function
result_sum = add_numbers(3, 7)
print("Sum:", result_sum)

# 1.14 Exceptions
# Handling exceptions and errors.

# Try-Except block
try:
    result = 10 / 0
except ZeroDivisionError:
    print("Cannot divide by zero!")

# 1.15 Program Termination
# Exiting a program using sys.exit().

import sys

print("Before sys.exit()")
# Note: In Colab, sys.exit() might not behave as expected, and a warning might be displayed.
# Instead, you can rely on Colab's runtime management or other ways to control program flow.

# sys.exit()
# This line won't be executed in Colab.

print("After sys.exit()")


# 1.16 Objects and Classes
# Introduction to object-oriented programming.

# Create a class
class Dog:
    def __init__(self, name, age):
        self.name = name
        self.age = age

    def bark(self):
        print("Woof!")

# Create an instance
my_dog = Dog("Buddy", 3)
print("Dog's name:", my_dog.name)
my_dog.bark()

# 1.17 Modules
# Using modules to organize code.

# Load the module content using 'exec'
module_content = """
def square(x):
    return x ** 2
"""

# Execute the module content
exec(module_content)

# Use the function from the module
result_square = square(5)
print("Square:", result_square)

# 1.18 Script Writing
# Writing Python scripts.

# Save the following code in a file named "myscript.py"
script_content = """
print("Hello from my script!")
"""

# Save the script content to a file
with open("myscript.py", "w") as script_file:
    script_file.write(script_content)

# Change the current working directory to the one containing your script
# %cd /path/to/directory/containing/myscript.py

# Run the script using %run
# %run myscript.py
# 1.19 Packages
# Organizing code into packages.

# Create a simple package structure
# !mkdir my_package
# !touch my_package/__init__.py
# !touch my_package/module.py

# Contents of module.py
module_content = """
def multiply(x, y):
    return x * y
"""

# Save the module content to the file
with open("my_package/module.py", "w") as module_file:
    module_file.write(module_content)

# Run the module using %run
# %run my_package/module.py

# Import and use the module
from my_package import module

result_multiply = module.multiply(3, 4)
print("Multiplication Result:", result_multiply)

# 1.20 Structuring an Application
# Tips for organizing and structuring a Python application.

# Basic project structure
# my_project/
# ├── main.py
# ├── utils/
# │   ├── __init__.py
# │   └── helper.py
# └── tests/
#     ├── __init__.py
#     └── test_helper.py

# Content of main.py
# from utils.helper import add_numbers

# result = add_numbers(10, 20)
# print("Sum:", result)

# 1.21 Managing Third-Party Packages
# Using external packages with pip.

# Install a third-party package
# Uncomment the next line to install the 'requests' package
# !pip install requests

# Use the installed package
import requests

response = requests.get("https://www.example.com")
print("Status Code:", response.status_code)

# End of the Colab notebook template
# Out:
# Hello, Python!
# Result of 5 + 3: 8
# Hello, John!
# Double age: 50
# Hello, Alice
# Addition: 15
# Multiplication: 50
# Division: 2.0
# Modulo: 1
# Odd number
# Iteration 0
# Iteration 1
# Iteration 2
# Length of text: 18
# Uppercase: PYTHON IS AWESOME!
# Substring: Python
# File Content: Hello, File!
# First element: 1
# Updated list: [1, 10, 3, 4, 5]
# X-coordinate: 4
# Unique Numbers: {1, 2, 3, 4, 5}
# Name: John
# Number: 1
# Number: 10
# Number: 3
# Number: 4
# Number: 5
# name: John
# age: 25
# city: New York
# Sum: 10
# Cannot divide by zero!
# Before sys.exit()
# After sys.exit()
# Dog's name: Buddy
# Woof!
# Square: 25
# [Errno 2] No such file or directory: '/path/to/directory/containing/myscript.py'
# /content
# Hello from my script!
# Multiplication Result: 12
# Status Code: 200
