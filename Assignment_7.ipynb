# %% [markdown]
# <a href="https://colab.research.google.com/github/revan006/CSC221_revan006/blob/main/Assignment_7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#6-1
person_0 = {'first name':'braden',
            'last name': 'schetter',
            'city':'Beacon'}
print(person_0['first name'])
print(person_0['last name'])
print(person_0['city'])
#6-2
number_0 = {'chris':'7',
            'braden':'4',
            'zach':'9',
            'sammy':'3',
            'dan':'1'}
print(number_0['braden'])
print(number_0['chris'])
print(number_0['dan'])
print(number_0['sammy'])
print(number_0['zach'])
#6-3/6-4
programming_glossary = {
    "lists": "Lists are ordered collections of items in Python. They are mutable, which means you can change their contents, and they can hold items of different data types.",
    "variable": "A variable is a named storage location in a program that holds data that can be changed during the program's execution.",
    "if": "The 'if' statement is a conditional statement in Python used to execute a block of code only if a specified condition is true. It can be followed by 'elif' and 'else' clauses for handling multiple conditions.",
    "strings": "Strings are sequences of characters in Python. They are enclosed in either single ('') or double (\"\") quotes and are used to represent text data.",
    "constants": "Constants are values that do not change during the program's execution. In Python, constants are typically represented using uppercase letters.",
    "dictionary": "A dictionary is an unordered collection of key-value pairs in Python. Each key is unique, and it is used to retrieve the corresponding value.",
    "loop": "A loop is a control structure in Python that allows you to repeat a block of code multiple times. Common types include 'for' and 'while' loops.",
    "function": "A function is a reusable block of code in Python that performs a specific task. It is defined using the 'def' keyword.",
    "module": "A module is a file containing Python code. It can define functions, variables, and classes that can be imported and used in other Python scripts.",
    "exception": "An exception is an event that occurs during the execution of a program and disrupts the normal flow of instructions. Python provides mechanisms to handle and raise exceptions."
}


for term, meaning in programming_glossary.items():
    print(f"Term: {term}")
    print(f"Meaning: {meaning}")
    print()
#6-11/6-12
city_data = {
    'cities': [
        {
            'name': 'New York City',
            'info': {
                'Country': 'United States',
                'Population Size': 8468000,
                'Additional Info': 'There are more than 800 languages spoken in New York'
            }
        },
        {
            'name': 'Venice',
            'info': {
                'Country': 'Italy',
                'Population Size': 261905,
                'Additional Info': 'Venice is known for its bridges'
            }
        },
        {
            'name': 'Manila',
            'info': {
                'Country': 'Philippines',
                'Population Size': 1780000,
                'Additional Info': 'Manila is one of the most densely populated cities in the world'
            }
        }
    ]
}

for city_info in city_data['cities']:
    print("Information about", city_info['name'] + ":")
    print("Country:", city_info['info']['Country'])
    print("Population Size:", city_info['info']['Population Size'])
    print("Additional Info:", city_info['info']['Additional Info'])
    print()
# Out:
# braden
# schetter
# Beacon
# 4
# 7
# 1
# 3
# 9
# Term: lists
# Meaning: Lists are ordered collections of items in Python. They are mutable, which means you can change their contents, and they can hold items of different data types.
#
# Term: variable
# Meaning: A variable is a named storage location in a program that holds data that can be changed during the program's execution.
#
# Term: if
# Meaning: The 'if' statement is a conditional statement in Python used to execute a block of code only if a specified condition is true. It can be followed by 'elif' and 'else' clauses for handling multiple conditions.
#
# Term: strings
# Meaning: Strings are sequences of characters in Python. They are enclosed in either single ('') or double ("") quotes and are used to represent text data.
#
# Term: constants
# Meaning: Constants are values that do not change during the program's execution. In Python, constants are typically represented using uppercase letters.
#
# Term: dictionary
# ...
